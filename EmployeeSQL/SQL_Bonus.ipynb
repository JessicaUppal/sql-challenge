# %%
#Import Dependencies
import pandas as pd
from config import username, password, db_name
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
#Establish connection
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/SQL_Challenge')
connection = engine.connect()

# %%
salary_df = pd.read_sql_table("salaries", con=engine)
salary_df
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
#Check axis min and max
print(salary_df["salary"].min())
print(salary_df["salary"].max())
# Out:
# 40000
# 129492

# %%
#Plot histogram to visualize the most common salary ranges for employees.
salary_df.salary.hist(figsize=(10,6), color='royalblue', alpha=0.75)
plt.title('Most Common Salary Ranges For Employees')
plt.xlabel('Salary')
plt.ylabel('Employee Count')
plt.show()

# %%
title_df = pd.read_sql_table("titles", con=engine)
title_df
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer
# 5    e0004    Technique Leader
# 6    m0001             Manager

# %%
#Read in employee dataframe
employee_df = pd.read_sql_table("employees", con=engine)
employee_df
# Out:
#         emp_no emp_title_id birth_date   first_name  last_name sex  hire_date
# 0       473302        s0001 1953-07-25     Hideyuki   Zallocco   M 1990-04-28
# 1       475053        e0002 1954-11-18        Byong  Delgrande   F 1991-09-07
# 2        57444        e0002 1958-01-30        Berry       Babb   F 1992-03-21
# 3       421786        s0001 1957-09-28        Xiong   Verhoeff   M 1987-11-26
# 4       282238        e0003 1952-10-28   Abdelkader    Baumann   F 1991-01-18
# ...        ...          ...        ...          ...        ...  ..        ...
# 300019  464231        s0001 1958-08-14  Constantino    Eastman   M 1988-10-28
# 300020  255832        e0002 1955-05-08       Yuping     Dayang   F 1995-02-26
# 300021   76671        s0001 1959-06-09       Ortrud   Plessier   M 1988-02-24
# 300022  264920        s0001 1959-09-22        Percy   Samarati   F 1994-09-08
# 300023  464503        s0002 1964-05-31       Arvind  Slobodova   M 1987-11-23
#
# [300024 rows x 7 columns]

# %%
#Rename emp_title_id column 
employee_df = employee_df.rename(columns={"emp_title_id":"title_id"})
employee_df
# Out:
#         emp_no title_id birth_date   first_name  last_name sex  hire_date
# 0       473302    s0001 1953-07-25     Hideyuki   Zallocco   M 1990-04-28
# 1       475053    e0002 1954-11-18        Byong  Delgrande   F 1991-09-07
# 2        57444    e0002 1958-01-30        Berry       Babb   F 1992-03-21
# 3       421786    s0001 1957-09-28        Xiong   Verhoeff   M 1987-11-26
# 4       282238    e0003 1952-10-28   Abdelkader    Baumann   F 1991-01-18
# ...        ...      ...        ...          ...        ...  ..        ...
# 300019  464231    s0001 1958-08-14  Constantino    Eastman   M 1988-10-28
# 300020  255832    e0002 1955-05-08       Yuping     Dayang   F 1995-02-26
# 300021   76671    s0001 1959-06-09       Ortrud   Plessier   M 1988-02-24
# 300022  264920    s0001 1959-09-22        Percy   Samarati   F 1994-09-08
# 300023  464503    s0002 1964-05-31       Arvind  Slobodova   M 1987-11-23
#
# [300024 rows x 7 columns]

# %%
#Merge title dataframe with employee dataframe 
merged_df = pd.merge(employee_df, title_df, on="title_id", how="inner")
merged_df
# Out:
#         emp_no title_id birth_date  first_name   last_name sex  hire_date  \
# 0       473302    s0001 1953-07-25    Hideyuki    Zallocco   M 1990-04-28
# 1       421786    s0001 1957-09-28       Xiong    Verhoeff   M 1987-11-26
# 2       273487    s0001 1957-04-14   Christoph     Parfitt   M 1991-06-28
# 3       246449    s0001 1958-03-23       Subbu  Bultermann   F 1988-03-25
# 4        48085    s0001 1964-01-19  Venkatesan        Gilg   M 1993-06-28
# ...        ...      ...        ...         ...         ...  ..        ...
# 300019  111400    m0001 1959-11-09        Arie     Staelin   M 1985-01-01
# 300020  111133    m0001 1955-03-16       Hauke       Zhang   M 1986-12-30
# 300021  110085    m0001 1959-10-28        Ebru       Alpin   M 1985-01-01
# 300022  110386    m0001 1953-10-04        Shem      Kieras   M 1988-10-14
# 300023  111784    m0001 1956-06-14       Marjo  Giarratana   F 1988-02-12
#
#           title
# 0         Staff
# 1         Staff
# 2         Staff
# ...

# %%
#Merge the dataframes together 
salary_merge_df = pd.merge(merged_df, salary_df, on="emp_no", how="inner")
salary_merge_df
# Out:
#         emp_no title_id birth_date  first_name   last_name sex  hire_date  \
# 0       473302    s0001 1953-07-25    Hideyuki    Zallocco   M 1990-04-28
# 1       421786    s0001 1957-09-28       Xiong    Verhoeff   M 1987-11-26
# 2       273487    s0001 1957-04-14   Christoph     Parfitt   M 1991-06-28
# 3       246449    s0001 1958-03-23       Subbu  Bultermann   F 1988-03-25
# 4        48085    s0001 1964-01-19  Venkatesan        Gilg   M 1993-06-28
# ...        ...      ...        ...         ...         ...  ..        ...
# 300019  111400    m0001 1959-11-09        Arie     Staelin   M 1985-01-01
# 300020  111133    m0001 1955-03-16       Hauke       Zhang   M 1986-12-30
# 300021  110085    m0001 1959-10-28        Ebru       Alpin   M 1985-01-01
# 300022  110386    m0001 1953-10-04        Shem      Kieras   M 1988-10-14
# 300023  111784    m0001 1956-06-14       Marjo  Giarratana   F 1988-02-12
#
#           title  salary
# 0         Staff   40000
# 1         Staff   40000
# ...

# %%
#Calculate average salary and group by title 
grouped_title = salary_merge_df.groupby(["title"])
average_salary = round(grouped_title["salary"].mean())
print(average_salary)
# Out:
# title
# Assistant Engineer    48564.0
# Engineer              48535.0
# Manager               51531.0
# Senior Engineer       48507.0
# Senior Staff          58550.0
# Staff                 58465.0
# Technique Leader      48583.0
# Name: salary, dtype: float64

# %%
#Plot bar average salary bar chart
average_salary.plot.bar(figsize=(10,6), color='slateblue', alpha=0.75)
plt.title("Average Salary by Title")
plt.xlabel("Title")
plt.ylabel("Average Salary")

# %%
#Epilogue
employee_df.loc[employee_df['emp_no']==499942]
# Out:
#         emp_no title_id birth_date first_name last_name sex  hire_date
# 168736  499942    e0004 1963-01-10      April  Foolsday   F 1997-02-10
